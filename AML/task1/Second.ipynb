# %%
import pandas as pd
import numpy as np
from numpy import sort
from sklearn.impute import SimpleImputer
from xgboost import XGBRegressor
from xgboost import plot_importance
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score,KFold
#from sklearn.neighbors import LocalOutlierFactor
from matplotlib import pyplot
from sklearn.metrics import r2_score
from sklearn.feature_selection import SelectFromModel
from sklearn.ensemble import IsolationForest

# %%
# Load Data for training:
df_train_features = pd.read_csv('X_train.csv')
Y = pd.read_csv('y_train.csv')

# Load Data for test
df_test_features = pd.read_csv('X_test.csv')

# %%
# Creates Train & Validation set with the relevant Data

def Vector(feature,label):
    label=label.iloc[:,1]
    feature=feature.iloc[:,1:]
    featurecorrected=SimpleImputer(strategy='median').fit_transform(feature)
    X_train, X_test, y_train, y_test  = train_test_split(featurecorrected,label, test_size=0.2, random_state=222)
    return X_train, X_test, y_train, y_test

# %%
def Outlier(X_train,y_train):
    detect=IsolationForest( n_estimators=1000,random_state=222)
    judge= detect.fit_predict(X_train)
    n=judge != -1
    x_train_adj = X_train[n, :]
    y_train_adj = y_train[n]
    return x_train_adj, y_train_adj

# %%
X_train, X_test, y_train, y_test= Vector(df_train_features,Y)

X_train_fin, y_train_fin=Outlier(X_train,y_train)

# %%
test_feature=df_test_features.iloc[:,1:]
test_featurecorrected=SimpleImputer(strategy='median').fit_transform(test_feature)

# %%
# Model XGBoost

model=XGBRegressor(n_estimators=1000,max_depth=8,learning_rate=0.05,random_state=222)

# %%
# Creates and fits with Train & Validation set


y1 = model.fit(X_train_fin, y_train_fin, early_stopping_rounds=20, 
             eval_set=[(X_test, y_test)], verbose=False)

# %%
ax = plot_importance(model)
ax.figure.set_size_inches(80,64)
pyplot.show()

# %%
preaccuracy=0
predictions = model.predict(X_test)
#predictions = np.round(predictions)
accuracy = r2_score(y_test, predictions)
print("Accuracy: %.2f%%" % (accuracy * 100.0))
# Fit model using each importance as a threshold
thresholds = -sort(-model.feature_importances_)
for thresh in thresholds:
    # select features using threshold
    selection = SelectFromModel(model,threshold=thresh, prefit=True)
    select_X_train = selection.transform(X_train_fin)
    # train model
    selection_model = XGBRegressor(n_estimators=1000,max_depth=8,learning_rate=0.05,random_state=222)
    select_X_test = selection.transform(X_test)
    selection_model.fit(select_X_train, y_train_fin, eval_set=[(select_X_test, y_test)], early_stopping_rounds=20, verbose=False)
    # eval model
    #select_X_test = selection.transform(X_test)
    predictions = selection_model.predict(select_X_test)
    #predictions = np.round(predictions)
    accuracy = r2_score(y_test, predictions)
    if accuracy> preaccuracy:
        testset= selection.transform(test_featurecorrected)
        result = selection_model.predict(testset)
        #result_round=np.round(result)
        # Create a data frame with the data for the submission
        d = {'id': df_test_features.iloc[:,0], 'y': result}

        df = pd.DataFrame(data=d)

        # Store the data in a csv file
        df.to_csv('prediction7.csv', index=False)
        print("saved " , select_X_train.shape[1])
        preaccuracy= accuracy
    print("Thresh=%.3f, n=%d, Accuracy: %.2f%%" % (thresh, select_X_train.shape[1], accuracy*100.0))
    if select_X_train.shape[1] == 400:
        break
# Out:
# Accuracy: 44.37%
# saved  1
# Thresh=0.074, n=1, Accuracy: 15.83%
# saved  2
# Thresh=0.028, n=2, Accuracy: 21.93%
# saved  3
# Thresh=0.025, n=3, Accuracy: 24.77%
# saved  4
# Thresh=0.021, n=4, Accuracy: 25.09%
# saved  5
# Thresh=0.021, n=5, Accuracy: 28.87%
# Thresh=0.014, n=6, Accuracy: 28.64%
# saved  7
# Thresh=0.013, n=7, Accuracy: 30.16%
# saved  8
# Thresh=0.012, n=8, Accuracy: 33.34%
# Thresh=0.011, n=9, Accuracy: 33.20%
# saved  10
# Thresh=0.011, n=10, Accuracy: 34.65%
# Thresh=0.011, n=11, Accuracy: 34.02%
# saved  12
# Thresh=0.010, n=12, Accuracy: 37.52%
# Thresh=0.008, n=13, Accuracy: 36.22%
# saved  14
# Thresh=0.008, n=14, Accuracy: 37.77%
# Thresh=0.007, n=15, Accuracy: 37.64%
# Thresh=0.007, n=16, Accuracy: 36.51%
# saved  17
# Thresh=0.007, n=17, Accuracy: 40.58%
# saved  18
# Thresh=0.007, n=18, Accuracy: 41.57%
# Thresh=0.006, n=19, Accuracy: 35.73%
# Thresh=0.006, n=20, Accuracy: 38.13%
# Thresh=0.006, n=21, Accuracy: 38.17%
# Thresh=0.006, n=22, Accuracy: 39.49%
# Thresh=0.006, n=23, Accuracy: 37.30%
# Thresh=0.005, n=24, Accuracy: 38.17%
# Thresh=0.005, n=25, Accuracy: 36.61%
# Thresh=0.005, n=26, Accuracy: 34.90%
# Thresh=0.005, n=27, Accuracy: 35.14%
# Thresh=0.005, n=28, Accuracy: 37.02%
# Thresh=0.004, n=29, Accuracy: 37.96%
# Thresh=0.004, n=30, Accuracy: 39.82%
# Thresh=0.004, n=31, Accuracy: 40.72%
# Thresh=0.004, n=32, Accuracy: 40.79%
# Thresh=0.004, n=33, Accuracy: 40.90%
# Thresh=0.004, n=34, Accuracy: 39.82%
# saved  35
# Thresh=0.004, n=35, Accuracy: 41.71%
# saved  36
# Thresh=0.004, n=36, Accuracy: 43.04%
# Thresh=0.004, n=37, Accuracy: 42.64%
# Thresh=0.004, n=38, Accuracy: 42.57%
# Thresh=0.003, n=39, Accuracy: 42.72%
# Thresh=0.003, n=40, Accuracy: 43.00%
# saved  41
# Thresh=0.003, n=41, Accuracy: 45.12%
# Thresh=0.003, n=42, Accuracy: 44.36%
# Thresh=0.003, n=43, Accuracy: 42.80%
# Thresh=0.003, n=44, Accuracy: 43.67%
# Thresh=0.003, n=45, Accuracy: 43.70%
# Thresh=0.003, n=46, Accuracy: 44.49%
# Thresh=0.003, n=47, Accuracy: 43.53%
# Thresh=0.003, n=48, Accuracy: 44.07%
# Thresh=0.003, n=49, Accuracy: 44.17%
# Thresh=0.003, n=50, Accuracy: 43.71%
# Thresh=0.003, n=51, Accuracy: 45.03%
# Thresh=0.003, n=52, Accuracy: 45.00%
# Thresh=0.003, n=53, Accuracy: 45.08%
# saved  54
# Thresh=0.003, n=54, Accuracy: 46.00%
# Thresh=0.003, n=55, Accuracy: 45.29%
# Thresh=0.003, n=56, Accuracy: 45.25%
# saved  57
# Thresh=0.003, n=57, Accuracy: 46.66%
# saved  58
# Thresh=0.003, n=58, Accuracy: 46.87%
# Thresh=0.003, n=59, Accuracy: 44.18%
# saved  60
# Thresh=0.003, n=60, Accuracy: 47.38%
# Thresh=0.003, n=61, Accuracy: 45.99%
# Thresh=0.003, n=62, Accuracy: 46.30%
# saved  63
# Thresh=0.003, n=63, Accuracy: 47.78%
# Thresh=0.002, n=64, Accuracy: 46.79%
# Thresh=0.002, n=65, Accuracy: 46.20%
# Thresh=0.002, n=66, Accuracy: 47.71%
# Thresh=0.002, n=67, Accuracy: 47.15%
# Thresh=0.002, n=68, Accuracy: 45.73%
# Thresh=0.002, n=69, Accuracy: 47.23%
# saved  70
# Thresh=0.002, n=70, Accuracy: 48.46%
# Thresh=0.002, n=71, Accuracy: 45.83%
# Thresh=0.002, n=134, Accuracy: 44.74%
# Thresh=0.002, n=135, Accuracy: 42.52%
# Thresh=0.002, n=136, Accuracy: 44.71%
# Thresh=0.002, n=137, Accuracy: 42.99%
# Thresh=0.002, n=138, Accuracy: 43.31%
# Thresh=0.002, n=139, Accuracy: 42.93%
# Thresh=0.002, n=140, Accuracy: 44.68%
# Thresh=0.002, n=141, Accuracy: 43.63%
# Thresh=0.002, n=142, Accuracy: 44.46%
# Thresh=0.002, n=143, Accuracy: 44.26%
# Thresh=0.002, n=144, Accuracy: 42.56%
# Thresh=0.002, n=145, Accuracy: 43.20%
# Thresh=0.002, n=146, Accuracy: 43.37%
# Thresh=0.002, n=147, Accuracy: 44.35%
# Thresh=0.002, n=148, Accuracy: 43.46%
# Thresh=0.002, n=149, Accuracy: 44.53%
# Thresh=0.002, n=150, Accuracy: 43.87%
# Thresh=0.001, n=151, Accuracy: 43.65%
# Thresh=0.001, n=152, Accuracy: 43.22%
# Thresh=0.001, n=153, Accuracy: 45.89%
# Thresh=0.001, n=154, Accuracy: 44.81%
# Thresh=0.001, n=155, Accuracy: 45.09%
# Thresh=0.001, n=156, Accuracy: 44.91%
# Thresh=0.001, n=157, Accuracy: 46.30%
# Thresh=0.001, n=158, Accuracy: 44.65%
# Thresh=0.001, n=159, Accuracy: 43.52%
# Thresh=0.001, n=160, Accuracy: 44.85%
# Thresh=0.001, n=161, Accuracy: 45.68%
# Thresh=0.001, n=162, Accuracy: 46.48%
# Thresh=0.001, n=163, Accuracy: 45.45%
# Thresh=0.001, n=164, Accuracy: 43.71%
# Thresh=0.001, n=165, Accuracy: 43.94%
# Thresh=0.001, n=166, Accuracy: 43.12%
# Thresh=0.001, n=167, Accuracy: 44.59%
# Thresh=0.001, n=168, Accuracy: 43.86%
# Thresh=0.001, n=169, Accuracy: 44.76%
# Thresh=0.001, n=170, Accuracy: 44.30%
# Thresh=0.001, n=171, Accuracy: 44.18%
# Thresh=0.001, n=172, Accuracy: 44.53%
# Thresh=0.001, n=173, Accuracy: 44.29%
# Thresh=0.001, n=174, Accuracy: 41.55%
# Thresh=0.001, n=175, Accuracy: 43.52%
# Thresh=0.001, n=176, Accuracy: 43.29%
# Thresh=0.001, n=177, Accuracy: 44.39%
# Thresh=0.001, n=178, Accuracy: 42.65%
# Thresh=0.001, n=179, Accuracy: 43.61%
# Thresh=0.001, n=180, Accuracy: 43.78%
# Thresh=0.001, n=181, Accuracy: 44.11%
# Thresh=0.001, n=182, Accuracy: 44.60%
# Thresh=0.001, n=183, Accuracy: 43.94%
# Thresh=0.001, n=184, Accuracy: 45.76%
# Thresh=0.001, n=185, Accuracy: 42.27%
# Thresh=0.001, n=186, Accuracy: 43.05%
# Thresh=0.001, n=187, Accuracy: 41.68%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16640/2213397945.py in <module>
#      13     selection_model = XGBRegressor(n_estimators=1000,max_depth=8,learning_rate=0.05,random_state=222)
#      14     select_X_test = selection.transform(X_test)
# ---> 15     selection_model.fit(select_X_train, y_train_fin, eval_set=[(select_X_test, y_test)], early_stopping_rounds=20, verbose=False)
#      16     # eval model
#      17     #select_X_test = selection.transform(X_test)
#
# ~\anaconda3\lib\site-packages\xgboost\core.py in inner_f(*args, **kwargs)
#     504         for k, arg in zip(sig.parameters, args):
#     505             kwargs[k] = arg
# --> 506         return f(**kwargs)
#     507
#     508     return inner_f
#
# ~\anaconda3\lib\site-packages\xgboost\sklearn.py in fit(self, X, y, sample_weight, base_margin, eval_set, eval_metric, early_stopping_rounds, verbose, xgb_model, sample_weight_eval_set, base_margin_eval_set, feature_weights, callbacks)
#     787
#     788         model, feval, params = self._configure_fit(xgb_model, eval_metric, params)
# --> 789         self._Booster = train(
#     790             params,
#     791             train_dmatrix,
#
# ~\anaconda3\lib\site-packages\xgboost\training.py in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks)
#     186     Booster : a trained booster model
#     187     """
# --> 188     bst = _train_internal(params, dtrain,
#     189                           num_boost_round=num_boost_round,
#     190                           evals=evals,
#
# ~\anaconda3\lib\site-packages\xgboost\training.py in _train_internal(params, dtrain, num_boost_round, evals, obj, feval, xgb_model, callbacks, evals_result, maximize, verbose_eval, early_stopping_rounds)
#      79         if callbacks.before_iteration(bst, i, dtrain, evals):
#      80             break
# ---> 81         bst.update(dtrain, i, obj)
#      82         if callbacks.after_iteration(bst, i, dtrain, evals):
#      83             break
#
# ~\anaconda3\lib\site-packages\xgboost\core.py in update(self, dtrain, iteration, fobj)
#    1678
#    1679         if fobj is None:
# -> 1680             _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#    1681                                                     ctypes.c_int(iteration),
#    1682                                                     dtrain.handle))
#
# KeyboardInterrupt:
